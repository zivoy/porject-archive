# %%
from random import random
r = {i:["element" for _ in range(round(random()*4)+1)] for i in range(1000000)}
len(r)
# Out:
# 1000000

# %%
#%%timeit
lookFor = set(range(3000,80000,23))
len(lookFor)
# Out:
# 3348

# %%
# %%timeit
results={i:r[i] for i in set(r.keys()).intersection(lookFor)}
# Out:
# 109 ms ± 4.68 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
{i:r[i] for i in set(r.keys()).intersection(lookFor)}
# Out:
# {65537: ['element', 'element', 'element', 'element', 'element'],
#  16386: ['element', 'element', 'element'],
#  57349: ['element', 'element', 'element'],
#  8198: ['element', 'element', 'element', 'element'],
#  49161: ['element', 'element', 'element'],
#  40973: ['element', 'element'],
#  32785: ['element', 'element', 'element', 'element'],
#  73748: ['element', 'element', 'element', 'element'],
#  24597: ['element', 'element', 'element'],
#  65560: ['element', 'element'],
#  16409: ['element', 'element', 'element', 'element', 'element'],
#  57372: ['element', 'element', 'element', 'element', 'element'],
#  8221: ['element', 'element', 'element', 'element'],
#  49184: ['element', 'element'],
#  40996: ['element'],
#  32808: ['element', 'element', 'element', 'element'],
#  73771: ['element'],
#  24620: ['element', 'element', 'element', 'element', 'element'],
#  65583: ['element', 'element'],
#  16432: ['element', 'element', 'element', 'element', 'element'],
# ...
